# %% [markdown]
# # Test Notebook
#
# This is to check if our Data Science libraries + local imports are working as expected

# %%
# %load nb_init.py
# sys path hack for importing sibling packages like "common" in our case
import sys

sys.path.insert(0, "..")

# %%
from src.common import utils

utils.verify_import()
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt

noise = np.random.random(size=(256, 256, 3))
plt.imshow(noise)

# %%
import tensorflow as tf

print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import tensorflow as tf
import numpy as np

input_img = np.random.random(size=(10, 256, 256, 3))
layer = tf.keras.layers.RandomZoom(0.5, 0.2)
out_img = layer(input_img)

out_img.shape
# Out:
# TensorShape([10, 256, 256, 3])
